# %%
import pandas as pd
df=pd.read_csv('cancer_data.csv')
df
# Out:
#                       cancer_type  new_cases_number  new_cases_rank  \
# 0                            Anus              5452              30
# 1                         Bladder             21096              17
# 2   Brain, central nervous system             31460              14
# 3                          Breast            178361               1
# 4                    Cervix uteri            123907               3
# 5                           Colon             31646              13
# 6                    Corpus uteri             16413              22
# 7                     Gallbladder             19570              20
# 8                Hodgkin lymphoma              9221              26
# 9                     Hypopharynx             28489              15
# 10                 Kaposi sarcoma                66              35
# 11                         Kidney             16861              21
# 12                         Larynx             34687              11
# ...

# %%
df.count()
# Out:
# cancer_type               35
# new_cases_number          35
# new_cases_rank            35
# new_case_percent          35
# new_cases_cum_risk        35
# Deaths Number             35
# death_rank                35
# death_percentage          35
# Deaths_cum_risk           35
# risk_of_prevalence_5yr    35
# per100k_5yr_prevalence    35
# dtype: int64

# %%
df.isnull().sum()
# Out:
# cancer_type               0
# new_cases_number          0
# new_cases_rank            0
# new_case_percent          0
# new_cases_cum_risk        0
# Deaths Number             0
# death_rank                0
# death_percentage          0
# Deaths_cum_risk           0
# risk_of_prevalence_5yr    0
# per100k_5yr_prevalence    0
# dtype: int64

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.heatmap(df.isnull())
plt.show()

# %%
# show cancer type and new case number
df.head()
# Out:
#                      cancer_type  new_cases_number  new_cases_rank  \
# 0                           Anus              5452              30
# 1                        Bladder             21096              17
# 2  Brain, central nervous system             31460              14
# 3                         Breast            178361               1
# 4                   Cervix uteri            123907               3
#
#    new_case_percent  new_cases_cum_risk  Deaths Number  death_rank  \
# 0              0.41                0.05           2776          29
# 1              1.60                0.19          11154          21
# 2              2.40                0.22          26656          10
# 3             13.50                2.81          90408           1
# 4              9.40                2.01          77348           2
#
#    death_percentage  Deaths_cum_risk  risk_of_prevalence_5yr  \
# 0              0.33             0.03                   12278
# ...

# %%
df.groupby('cancer_type').sum()
# Out:
#                                new_cases_number  new_cases_rank  \
# cancer_type
# Anus                                       5452              30
# Bladder                                   21096              17
# Brain, central nervous system             31460              14
# Breast                                   178361               1
# Cervix uteri                             123907               3
# Colon                                     31646              13
# Corpus uteri                              16413              22
# Gallbladder                               19570              20
# Hodgkin lymphoma                           9221              26
# Hypopharynx                               28489              15
# Kaposi sarcoma                               66              35
# Kidney                                    16861              21
# Larynx                                    34687              11
# ...

# %%
#group by region only for particular column
df.groupby('cancer_type')['new_cases_number'].sum().sort_values(ascending=False)
# Out:
# cancer_type
# Breast                           178361
# Lip, oral cavity                 135929
# Cervix uteri                     123907
# Lung                              72510
# Oesophagus                        63180
# Stomach                           60222
# Leukaemia                         48419
# Ovary                             45701
# Non-Hodgkin lymphoma              35828
# Liver                             34743
# Larynx                            34687
# Prostate                          34540
# Colon                             31646
# Brain, central nervous system     31460
# Hypopharynx                       28489
# Rectum                            28260
# Bladder                           21096
# Oropharynx                        20617
# Thyroid                           20432
# Gallbladder                       19570
# Kidney                            16861
# Corpus uteri                      16413
# Multiple myeloma                  14641
# ...

# %%
#seeing the case number which is less than 1000
df[df.new_cases_number<1000]
# Out:
#        cancer_type  new_cases_number  new_cases_rank  new_case_percent  \
# 10  Kaposi sarcoma                66              35               0.0
#
#     new_cases_cum_risk  Deaths Number  death_rank  death_percentage  \
# 10                 0.0             43          35              0.01
#
#     Deaths_cum_risk  risk_of_prevalence_5yr  per100k_5yr_prevalence
# 10              0.0                     156                    0.01

# %%
#seeing the case number which is greater than 1000
df[df.new_cases_number>1000]
# Out:
#                       cancer_type  new_cases_number  new_cases_rank  \
# 0                            Anus              5452              30
# 1                         Bladder             21096              17
# 2   Brain, central nervous system             31460              14
# 3                          Breast            178361               1
# 4                    Cervix uteri            123907               3
# 5                           Colon             31646              13
# 6                    Corpus uteri             16413              22
# 7                     Gallbladder             19570              20
# 8                Hodgkin lymphoma              9221              26
# 9                     Hypopharynx             28489              15
# 11                         Kidney             16861              21
# 12                         Larynx             34687              11
# 13                      Leukaemia             48419               7
# ...

# %%
#finding which type of cancer has highest number of cases
df.groupby('cancer_type').new_cases_number.sum().sort_values(ascending=False).head(20)
# Out:
# cancer_type
# Breast                           178361
# Lip, oral cavity                 135929
# Cervix uteri                     123907
# Lung                              72510
# Oesophagus                        63180
# Stomach                           60222
# Leukaemia                         48419
# Ovary                             45701
# Non-Hodgkin lymphoma              35828
# Liver                             34743
# Larynx                            34687
# Prostate                          34540
# Colon                             31646
# Brain, central nervous system     31460
# Hypopharynx                       28489
# Rectum                            28260
# Bladder                           21096
# Oropharynx                        20617
# Thyroid                           20432
# Gallbladder                       19570
# Name: new_cases_number, dtype: int64

# %%
#seeing which type of cancre has less number of deaths
df.groupby('cancer_type').death_percentage.sum().sort_values().head(20)
# Out:
# cancer_type
# Kaposi sarcoma      0.01
# Testis              0.15
# Mesothelioma        0.18
# Vulva               0.20
# Melanoma of skin    0.27
# Vagina              0.32
# Anus                0.33
# Hodgkin lymphoma    0.41
# Nasopharynx         0.49
# Penis               0.56
# Thyroid             0.57
# Salivary glands     0.60
# Corpus uteri        0.75
# Kidney              1.20
# Hypopharynx         1.30
# Bladder             1.30
# Pancreas            1.40
# Oropharynx          1.50
# Multiple myeloma    1.50
# Gallbladder         1.70
# Name: death_percentage, dtype: float64

# %%
import matplotlib.pyplot as plt
import pandas as pd
df =pd.read_csv('cancer_data.csv')
cancer=['cancer_type','new_cases_number','death_percentage','risk_of_prevalence_5yr']
rate=[1,2,3,4]
plt.pie(rate,labels=cancer,radius=1.7,autopct='%0.1f%%',explode=[0,0.1,0,0],startangle=180)
plt.show()

# %%
#seeing which type of cancer has minimum number of risk prevelence per 5 year
import pandas as pd
df.groupby('cancer_type').risk_of_prevalence_5yr.sum().sort_values().head(20)
# Out:
# cancer_type
# Kaposi sarcoma        156
# Mesothelioma         2223
# Vulva                8928
# Melanoma of skin     9637
# Pancreas            11928
# Anus                12278
# Vagina              12315
# Nasopharynx         14196
# Testis              14812
# Salivary glands     20448
# Hodgkin lymphoma    24928
# Gallbladder         25138
# Penis               26280
# Multiple myeloma    30640
# Liver               38602
# Kidney              39150
# Hypopharynx         39750
# Corpus uteri        43484
# Oropharynx          44398
# Bladder             49257
# Name: risk_of_prevalence_5yr, dtype: int64

# %%
#sort the new cases in ascending order
df.sort_values(by=['new_cases_number'])
# Out:
#                       cancer_type  new_cases_number  new_cases_rank  \
# 10                 Kaposi sarcoma                66              35
# 18                   Mesothelioma              1709              34
# 34                          Vulva              3447              33
# 17               Melanoma of skin              3916              32
# 31                         Testis              4681              31
# 0                            Anus              5452              30
# 33                         Vagina              5518              29
# 20                    Nasopharynx              5697              28
# 29                Salivary glands              7850              27
# 8                Hodgkin lymphoma              9221              26
# 26                          Penis             10677              25
# 25                       Pancreas             12642              24
# 19               Multiple myeloma             14641              23
# ...

# %%
#sort the new cases in ascending order
df.sort_values(by=['new_cases_number'],ascending=False)
# Out:
#                       cancer_type  new_cases_number  new_cases_rank  \
# 3                          Breast            178361               1
# 14               Lip, oral cavity            135929               2
# 4                    Cervix uteri            123907               3
# 16                           Lung             72510               4
# 22                     Oesophagus             63180               5
# 30                        Stomach             60222               6
# 13                      Leukaemia             48419               7
# 24                          Ovary             45701               8
# 21           Non-Hodgkin lymphoma             35828               9
# 15                          Liver             34743              10
# 12                         Larynx             34687              11
# 27                       Prostate             34540              12
# 5                           Colon             31646              13
# ...
